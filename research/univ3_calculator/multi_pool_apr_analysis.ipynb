# %%
import pandas as pd
import numpy as np
import json
import os
import requests
import time
from decimal import getcontext
from datetime import datetime
from typing import Dict, List, Tuple, Optional
import warnings
from uniswapv3_calculator import UniswapV3Calculator
warnings.filterwarnings('ignore')

# Set high precision for accurate calculations
getcontext().prec = 50

# %%
# Configuration: List of pools to analyze
POOLS_CONFIG = [
    {
        "pool_addr": "0x5969efdde3cf5c0d9a88ae51e47d721096a97203",
        "token0": "0x2f2a2543b76a4166549f7aab2e75bef0aefc5b0f",  # WBTC
        "token1": "0xfd086bc7cd5c481dcc9c85ebe478a1c0b69fcbb9",  # USDT
        "is_pair_toggled": False,
        "deposit_amount_usd": 100000
    },
    {
        "pool_addr": "0xc6962004f452be9203591991d15f6b388e09e8d0",
        "token0": "0x82af49447d8a07e3bd95bd0d56f35241523fbab1",  # WETH
        "token1": "0xaf88d065e77c8cc2239327c5edb3a432268e5831",  # USDC
        "is_pair_toggled": False,
        "deposit_amount_usd": 100000
    },
    {
        "pool_addr": "0x2f5e87C9312fa29aed5c179E456625D79015299c",
        "token0": "0x2f2a2543B76A4166549F7aaB2e75Bef0aefC5B0f",  # WBTC
        "token1": "0x82af49447d8a07e3bd95bd0d56f35241523fbab1",  # WETH
        "is_pair_toggled": False,
        "deposit_amount_usd": 100000
    },
    {
        "pool_addr": "0x641C00A822e8b671738d32a431a4Fb6074E5c79d",
        "token0": "0x82af49447d8a07e3bd95bd0d56f35241523fbab1",  # WETH
        "token1": "0xfd086bc7cd5c481dcc9c85ebe478a1c0b69fcbb9",  # USDT
        "is_pair_toggled": False,
        "deposit_amount_usd": 100000
    },
    {
        "pool_addr": "0x6f38e884725a116C9C7fBF208e79FE8828a2595F",
        "token0": "0x82af49447d8a07e3bd95bd0d56f35241523fbab1",  # WETH
        "token1": "0xaf88d065e77c8cc2239327c5edb3a432268e5831",  # USDC
        "is_pair_toggled": False,
        "deposit_amount_usd": 100000
    },
    {
        "pool_addr": "0xC6F780497A95e246EB9449f5e4770916DCd6396A",
        "token0": "0x82af49447d8a07e3bd95bd0d56f35241523fbab1",  # WETH
        "token1": "0x912CE59144191C1204E64559FE8253a0e49E6548",  # ARB
        "is_pair_toggled": False,
        "deposit_amount_usd": 100000
    },
    {
        "pool_addr": "0xcDa53B1F66614552F834cEeF361A8D12a0B8DaD8",
        "token0": "0x912CE59144191C1204E64559FE8253a0e49E6548",  # ARB
        "token1": "0xFF970A61A04b1cA14834A43f5dE4533eBDDB5CC8",  # USDC.e
        "is_pair_toggled": False,
        "deposit_amount_usd": 100000
    },
    {
        "pool_addr": "0x50e7B9293aeF80c304234e86C84a01bE8401C530",
        "token0": "0x0c880f6761F1af8d9Aa9C466984b80DAb9a8c9e8",  # PENDLE
        "token1": "0xFd086bC7CD5C481DCC9C85ebE478A1C0b69FCbb9",  # USDC.e
        "is_pair_toggled": False,
        "deposit_amount_usd": 100000
    },
]

# Whether to force fetch data instead of using cache
NO_CACHE = True

# The Graph endpoint for Uniswap V3 on Arbitrum
GRAPH_URL = "https://gateway-arbitrum.network.thegraph.com/api/418eadaa2d81cca124449b86392c8a70/subgraphs/id/FbCGRftH4a3yZugY7TnbYgPJVEv2LvMT6oF1fxPe9aJM"

# Range percentages to test
RANGE_PERCENTAGES = np.arange(0.5, 20.5, 0.5)

# %%
def lowercase_addresses(pool_config):
    for entry in pool_config:
        for key in ["pool_addr", "token0", "token1"]:
            if key in entry and isinstance(entry[key], str):
                entry[key] = entry[key].lower()
    return pool_config

POOLS_CONFIG = lowercase_addresses(POOLS_CONFIG)

# %%
# Data fetching functions (from notebook 1)
def query_graph(query: str, variables: Dict = None) -> Dict:
    """
    Query The Graph API
    """
    payload = {
        "query": query,
        "variables": variables or {}
    }
    
    try:
        response = requests.post(GRAPH_URL, json=payload, timeout=30)
        response.raise_for_status()
        data = response.json()
        
        if "errors" in data:
            print(f"GraphQL errors: {data['errors']}")
            return {}
            
        return data.get("data", {})
    except Exception as e:
        print(f"Error querying The Graph: {e}")
        return {}

def get_pool_day_data(pool_address: str, num_days: int = 90) -> List[Dict]:
    """
    Get historical pool day data for volume calculation
    """
    query = f"""
    {{
        poolDayDatas(first: {num_days}, orderBy: date, orderDirection: desc, where: {{pool: "{pool_address.lower()}"}}) {{
            date
            volumeUSD
            tvlUSD
            feesUSD
            open
            high
            low
            close
        }}
    }}
    """
    
    result = query_graph(query)
    return result.get("poolDayDatas", [])

def get_pool_ticks(pool_address: str, skip: int = 0, first: int = 1000) -> List[Dict]:
    """
    Get pool ticks data for liquidity calculation
    """
    query = f"""
    {{
        ticks(first: {first}, skip: {skip}, where: {{poolAddress: "{pool_address.lower()}"}}, orderBy: tickIdx) {{
            tickIdx
            liquidityNet
            price0
            price1
        }}
    }}
    """
    
    result = query_graph(query)
    return result.get("ticks", [])

def get_all_pool_ticks(pool_address: str) -> List[Dict]:
    """
    Get all ticks for a pool (paginated)
    """
    all_ticks = []
    skip = 0
    batch_size = 1000
    
    while True:
        ticks = get_pool_ticks(pool_address, skip, batch_size)
        if not ticks:
            break
            
        all_ticks.extend(ticks)
        
        if len(ticks) < batch_size:
            break
            
        skip += batch_size
        time.sleep(0.1)  # Rate limiting
    
    return all_ticks

def get_token_data(token_address: str) -> Dict:
    """
    Get token data including decimals and current price from the Graph API
    """
    query = f"""
    {{
        token(id: "{token_address.lower()}") {{
            id
            name
            symbol
            decimals
            volumeUSD
            totalValueLockedUSD
            tokenDayData(first: 1, orderBy: date, orderDirection: desc) {{
                priceUSD
                date
            }}
        }}
    }}
    """
    
    result = query_graph(query)
    token = result.get("token", {})
    
    # Add priceUSD from the most recent tokenDayData
    if token and 'tokenDayData' in token and token['tokenDayData']:
        token['priceUSD'] = token['tokenDayData'][0]['priceUSD']
        del token['tokenDayData']  # Remove the raw data since we extracted what we need
        
    return token

def sort_tokens(token0_addr: str, token1_addr: str) -> List[str]:
    """
    Sort tokens by address (same as sortTokens in uniswap.ts)
    """
    if token0_addr.lower() < token1_addr.lower():
        return [token0_addr, token1_addr]
    return [token1_addr, token0_addr]

def get_pool_from_pair(token0_addr: str, token1_addr: str) -> List[Dict]:
    """
    Get pool data for a token pair (similar to getPoolFromPair in uniswap.ts)
    """
    sorted_tokens = sort_tokens(token0_addr, token1_addr)
    
    query = f"""
    {{
        pools(orderBy: feeTier, where: {{
            token0: "{sorted_tokens[0].lower()}",
            token1: "{sorted_tokens[1].lower()}"
        }}) {{
            id
            feeTier
            token0 {{
                id
                symbol
            }}
            token1 {{
                id
                symbol
            }}
        }}
    }}
    """
    
    result = query_graph(query)
    return result.get("pools", [])

# %%
# Data management functions
def check_data_exists(pool_addr: str) -> Tuple[bool, bool, bool]:
    """
    Check if pool data files exist
    Returns: (pool_day_data_exists, pool_ticks_data_exists, token_data_exists)
    """
    pool_day_exists = os.path.exists(f'{pool_addr}_pool_day_data.csv')
    pool_ticks_exists = os.path.exists(f'{pool_addr}_pool_ticks_data.csv')
    token_data_exists = os.path.exists(f'{pool_addr}_token_data.json')
    
    return pool_day_exists, pool_ticks_exists, token_data_exists

def fetch_and_save_pool_data(pool_config: Dict) -> bool:
    """
    Fetch and save pool data if it doesn't exist
    Returns True if successful, False otherwise
    """
    pool_addr = pool_config['pool_addr']
    token0 = pool_config['token0']
    token1 = pool_config['token1']
    
    try:
        print(f"📥 Fetching data for pool {pool_addr}...")
        
        # Validate pool address
        pools = get_pool_from_pair(token0, token1)
        if not pools:
            print(f"❌ No pools found for token pair {token0} and {token1}")
            return False

        # Find the pool with matching address
        pool_found = False
        for pool in pools:
            if pool['id'].lower() == pool_addr.lower():
                print(f"✅ Valid pool found: {pool['token0']['symbol']}/{pool['token1']['symbol']} (Fee: {int(pool['feeTier'])/1_000_000:.3%})")
                pool_found = True
                break

        if not pool_found:
            available_pools = "\n".join([f"- {p['id']} (Fee: {int(p['feeTier'])/1_000_000:.3%})" for p in pools])
            print(f"❌ Pool address {pool_addr} not found for this token pair.\nAvailable pools:\n{available_pools}")
            return False

        # Get pool data
        pool_day_data = get_pool_day_data(pool_addr, 90)
        pool_ticks_data = get_all_pool_ticks(pool_addr)

        # Get token data
        token0_data = get_token_data(token0)
        token1_data = get_token_data(token1)

        # Save pool data
        df = pd.DataFrame(pool_day_data)
        df.to_csv(f'{pool_addr}_pool_day_data.csv', index=False)

        df = pd.DataFrame(pool_ticks_data)
        df.to_csv(f'{pool_addr}_pool_ticks_data.csv', index=False)

        # Save token data
        token_data = {
            'token0': token0_data,
            'token1': token1_data,
            'pool': {
                'id': pool_addr,
                'feeTier': next(p['feeTier'] for p in pools if p['id'].lower() == pool_addr.lower())
            }
        }
        with open(f'{pool_addr}_token_data.json', 'w') as f:
            json.dump(token_data, f, indent=2)

        print(f"✅ Data saved for pool {pool_addr}")
        return True
        
    except Exception as e:
        print(f"❌ Error fetching data for pool {pool_addr}: {e}")
        return False

def load_pool_data(pool_addr: str) -> Tuple[pd.DataFrame, pd.DataFrame, Dict]:
    """
    Load pool data from files
    """
    pool_day_data = pd.read_csv(f'{pool_addr}_pool_day_data.csv')
    pool_ticks_data = pd.read_csv(f'{pool_addr}_pool_ticks_data.csv')
    
    with open(f'{pool_addr}_token_data.json', 'r') as f:
        token_data = json.load(f)
    
    return pool_day_data, pool_ticks_data, token_data

# %%
# APR calculation function
def calculate_apr_for_range(pool_config: Dict, range_pct: float, verbose: bool = False) -> Optional[float]:
    """
    Calculate APR for a specific pool and range percentage
    """
    pool_addr = pool_config['pool_addr']
    deposit_amount_usd = pool_config['deposit_amount_usd']
    is_pair_toggled = pool_config['is_pair_toggled']
    
    try:
        # Load data
        pool_day_data, pool_ticks_data, token_data = load_pool_data(pool_addr)
        
        # Set up token decimals and prices
        token0_decimal = int(token_data['token0']['decimals'])
        token1_decimal = int(token_data['token1']['decimals'])

        fee_tier = int(token_data['pool']['feeTier']) / 1_000_000
        
        price_usd_x = float(token_data['token0']['priceUSD'])
        price_usd_y = float(token_data['token1']['priceUSD'])

        # Initialize calculator
        calculator = UniswapV3Calculator(pool_day_data, pool_ticks_data, fee_tier, token0_decimal, token1_decimal, is_pair_toggled)

        if is_pair_toggled:
            P = pool_day_data.iloc[0]['close']
        else:
            P = 1 / pool_day_data.iloc[0]['close']

        range_decimal = range_pct / 100
        Pl = P * (1 - range_decimal)
        Pu = P * (1 + range_decimal)

        in_range = Pl <= P <= Pu
        if not in_range:
            if verbose:
                print(f"❌ Position is out of range for {range_pct}%!")
            return None

        # Calculate token amounts
        amount0, amount1, basic_liquidity_delta = calculator.get_tokens_amount_from_deposit_amount_usd(
            P, Pl, Pu, price_usd_x, price_usd_y, deposit_amount_usd
        )

        # Calculate deltaL
        corrected_delta_l = calculator.calculate_position_liquidity(
            amount0, amount1, Pl, Pu, P
        )

        # Get total liquidity
        current_tick = calculator.get_tick_from_price(P)
        total_liquidity = calculator.get_liquidity_from_tick(current_tick)

        # Calculate fees
        volume_24h = calculator.get_volume_24h_avg()
        estimated_fee_24h = calculator.estimate_fee(corrected_delta_l, abs(total_liquidity), volume_24h)

        yearly_fee = estimated_fee_24h * 365
        yearly_apr_pct = (yearly_fee / deposit_amount_usd) * 100

        return yearly_apr_pct
        
    except Exception as e:
        if verbose:
            print(f"❌ Error calculating APR for pool {pool_addr} at {range_pct}%: {e}")
        return None

def analyze_pool(pool_config: Dict) -> List[Dict]:
    """
    Analyze a single pool across all range percentages
    """
    pool_addr = pool_config['pool_addr']
    results = []
    
    print(f"\n🔄 Analyzing pool {pool_addr}...")
    
    # Check if data exists, if not fetch it
    pool_day_exists, pool_ticks_exists, token_data_exists = check_data_exists(pool_addr)
    
    if NO_CACHE or not (pool_day_exists and pool_ticks_exists and token_data_exists):
        if NO_CACHE:
            print(f"📥 Forcing data fetch (no_cache=True)...")
        else:
            print(f"📥 Data not found, fetching...")
            
        if not fetch_and_save_pool_data(pool_config):
            print(f"❌ Failed to fetch data for pool {pool_addr}")
            return results
    else:
        print(f"✅ Using cached data")
    
    # Load token data for pool info
    try:
        with open(f'{pool_addr}_token_data.json', 'r') as f:
            token_data = json.load(f)
        
        # Create base pool symbol and add fee tier
        base_pool_symbol = f"{token_data['token0']['symbol']}/{token_data['token1']['symbol']}"
        fee_tier_pct = int(token_data['pool']['feeTier']) / 1_000_000
        fee_tier_str = f"{fee_tier_pct:.2%}"
        pool_symbol = f"{base_pool_symbol} ({fee_tier_str})"
        
        print(f"📊 Pool: {pool_symbol}")
        
    except Exception as e:
        print(f"❌ Error loading token data: {e}")
        return results
    
    # Calculate APR for each range
    for range_pct in RANGE_PERCENTAGES:
        apr = calculate_apr_for_range(pool_config, range_pct)
        
        result = {
            'pool_address': pool_addr,
            'pool_symbol': pool_symbol,
            'base_pool_symbol': base_pool_symbol,  # Add base symbol for grouping
            'fee_tier_pct': fee_tier_pct,
            'deposit_amount_usd': pool_config['deposit_amount_usd'],
            'is_pair_toggled': pool_config['is_pair_toggled'],
            'range_percentage': range_pct,
            'apr_percentage': apr
        }
        
        results.append(result)
        
        if apr is not None:
            print(f"  ±{range_pct:4.1f}%: {apr:8.2f}% APR")
        else:
            print(f"  ±{range_pct:4.1f}%: Out of range")
    
    return results

# %%
# Main analysis function
def run_multi_pool_analysis():
    """
    Run APR analysis across all configured pools
    """
    print("🚀 Starting Multi-Pool APR Analysis")
    print(f"📊 Analyzing {len(POOLS_CONFIG)} pools")
    print(f"📈 Range: ±{RANGE_PERCENTAGES[0]}% to ±{RANGE_PERCENTAGES[-1]}%")
    print(f"🔢 Total calculations: {len(POOLS_CONFIG) * len(RANGE_PERCENTAGES)}")
    print("=" * 60)
    
    all_results = []
    
    # Analyze each pool
    for i, pool_config in enumerate(POOLS_CONFIG, 1):
        print(f"\n[{i}/{len(POOLS_CONFIG)}] Processing pool {pool_config['pool_addr']}")
        
        pool_results = analyze_pool(pool_config)
        all_results.extend(pool_results)
        
        # Small delay between pools to be nice to the API
        if i < len(POOLS_CONFIG):
            time.sleep(1)
    
    # Convert to DataFrame and save
    results_df = pd.DataFrame(all_results)
    
    # Filter out None values
    results_df = results_df.dropna(subset=['apr_percentage'])
    
    if len(results_df) == 0:
        print("\n❌ No valid results found!")
        return
    
    # Save comprehensive results
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f"multi_pool_apr_analysis_{timestamp}.csv"
    results_df.to_csv(filename, index=False)
    
    print(f"\n✅ Results saved to {filename}")
    print(f"\n📊 Analysis Summary:")
    print(f"Total valid results: {len(results_df)}")
    print(f"Pools analyzed: {results_df['pool_address'].nunique()}")
    
    return results_df

# %%
# Run the analysis
results_df = run_multi_pool_analysis()
# Out:
# 🚀 Starting Multi-Pool APR Analysis
# 📊 Analyzing 8 pools
# 📈 Range: ±0.5% to ±20.0%
# 🔢 Total calculations: 320
# ============================================================
#
# [1/8] Processing pool 0x5969efdde3cf5c0d9a88ae51e47d721096a97203
#
# 🔄 Analyzing pool 0x5969efdde3cf5c0d9a88ae51e47d721096a97203...
# 📥 Forcing data fetch (no_cache=True)...
# 📥 Fetching data for pool 0x5969efdde3cf5c0d9a88ae51e47d721096a97203...
# ✅ Valid pool found: WBTC/USDT (Fee: 0.050%)
# ✅ Data saved for pool 0x5969efdde3cf5c0d9a88ae51e47d721096a97203
# 📊 Pool: WBTC/USDT (0.05%)
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 5.85e+11
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 0.5%:   369.50% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 2.93e+11
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 1.0%:   203.27% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 1.95e+11
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 1.5%:   140.30% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 1.47e+11
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 2.0%:   107.18% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 1.18e+11
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 2.5%:    86.74% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 9.81e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 3.0%:    72.88% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 8.42e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 3.5%:    62.86% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 7.37e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 4.0%:    55.27% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 6.56e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 4.5%:    49.33% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 5.91e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 5.0%:    44.55% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 5.38e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 5.5%:    40.62% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 4.94e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 6.0%:    37.34% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 4.56e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 6.5%:    34.55% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 4.24e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 7.0%:    32.15% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 3.96e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 7.5%:    30.07% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 3.72e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 8.0%:    28.24% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 3.50e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 8.5%:    26.63% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 3.31e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 9.0%:    25.19% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 3.14e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ± 9.5%:    23.90% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 2.98e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±10.0%:    22.74% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 2.85e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±10.5%:    21.69% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 2.72e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±11.0%:    20.73% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 2.60e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±11.5%:    19.86% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 2.50e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±12.0%:    19.05% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 2.40e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±12.5%:    18.31% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 2.31e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±13.0%:    17.63% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 2.22e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±13.5%:    16.99% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 2.15e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±14.0%:    16.41% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 2.07e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±14.5%:    15.86% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 2.01e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±15.0%:    15.34% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 1.94e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±15.5%:    14.86% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 1.88e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±16.0%:    14.41% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 1.83e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±16.5%:    13.99% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 1.78e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±17.0%:    13.59% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 1.73e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±17.5%:    13.21% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 1.68e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±18.0%:    12.86% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 1.64e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±18.5%:    12.52% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 1.59e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±19.0%:    12.20% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 1.55e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±19.5%:    11.90% APR
# Current price (token0/token1): 0.000008398137
# Current price (token1/token0): 119074.03
# deltaL: 1.52e+10
# Average 24h volume (last 7 days): $11,231,491.61
#   ±20.0%:    11.61% APR
#
# [2/8] Processing pool 0xc6962004f452be9203591991d15f6b388e09e8d0
#
# 🔄 Analyzing pool 0xc6962004f452be9203591991d15f6b388e09e8d0...
# 📥 Forcing data fetch (no_cache=True)...
# 📥 Fetching data for pool 0xc6962004f452be9203591991d15f6b388e09e8d0...
# ✅ Valid pool found: WETH/USDC (Fee: 0.050%)
# ✅ Data saved for pool 0xc6962004f452be9203591991d15f6b388e09e8d0
# 📊 Pool: WETH/USDC (0.05%)
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 3.35e+17
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 0.5%:  1972.96% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.68e+17
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 1.0%:  1017.36% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.12e+17
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 1.5%:   685.95% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 8.41e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 2.0%:   517.71% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 6.74e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 2.5%:   415.94% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 5.62e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 3.0%:   347.74% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 4.82e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 3.5%:   298.85% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 4.22e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 4.0%:   262.08% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 3.76e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 4.5%:   233.43% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 3.39e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 5.0%:   210.47% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 3.08e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 5.5%:   191.65% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 2.83e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 6.0%:   175.96% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 2.61e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 6.5%:   162.66% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 2.43e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 7.0%:   151.26% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 2.27e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 7.5%:   141.36% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 2.13e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 8.0%:   132.70% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 2.01e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 8.5%:   125.05% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.90e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 9.0%:   118.24% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.80e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ± 9.5%:   112.15% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.71e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ±10.0%:   106.66% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.63e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ±10.5%:   101.70% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.56e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ±11.0%:    97.18% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.49e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ±11.5%:    93.05% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.43e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ±12.0%:    89.26% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.38e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ±12.5%:    85.78% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.32e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ±13.0%:    82.56% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.28e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ±13.5%:    79.58% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.23e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ±14.0%:    76.81% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.19e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ±14.5%:    74.23% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.15e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ±15.0%:    71.82% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.11e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ±15.5%:    69.56% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.08e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ±16.0%:    67.44% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.05e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ±16.5%:    65.45% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 1.02e+16
# Average 24h volume (last 7 days): $185,312,529.52
#   ±17.0%:    63.58% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 9.90e+15
# Average 24h volume (last 7 days): $185,312,529.52
#   ±17.5%:    61.81% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 9.64e+15
# Average 24h volume (last 7 days): $185,312,529.52
#   ±18.0%:    60.14% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 9.38e+15
# Average 24h volume (last 7 days): $185,312,529.52
#   ±18.5%:    58.56% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 9.14e+15
# Average 24h volume (last 7 days): $185,312,529.52
#   ±19.0%:    57.06% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 8.91e+15
# Average 24h volume (last 7 days): $185,312,529.52
#   ±19.5%:    55.64% APR
# Current price (token0/token1): 0.000287517711
# Current price (token1/token0): 3478.05
# deltaL: 8.70e+15
# Average 24h volume (last 7 days): $185,312,529.52
#   ±20.0%:    54.29% APR
#
# [3/8] Processing pool 0x2f5e87c9312fa29aed5c179e456625d79015299c
#
# 🔄 Analyzing pool 0x2f5e87c9312fa29aed5c179e456625d79015299c...
# 📥 Forcing data fetch (no_cache=True)...
# 📥 Fetching data for pool 0x2f5e87c9312fa29aed5c179e456625d79015299c...
# ✅ Valid pool found: WBTC/WETH (Fee: 0.050%)
# ✅ Data saved for pool 0x2f5e87c9312fa29aed5c179e456625d79015299c
# 📊 Pool: WBTC/WETH (0.05%)
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 9.77e+15
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 0.5%:   675.02% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 4.89e+15
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 1.0%:   346.52% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 3.26e+15
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 1.5%:   233.27% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 2.45e+15
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 2.0%:   175.90% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 1.96e+15
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 2.5%:   141.25% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 1.64e+15
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 3.0%:   118.04% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 1.40e+15
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 3.5%:   101.41% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 1.23e+15
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 4.0%:    88.91% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 1.10e+15
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 4.5%:    79.17% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 9.87e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 5.0%:    71.37% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 8.98e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 5.5%:    64.98% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 8.24e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 6.0%:    59.65% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 7.61e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 6.5%:    55.13% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 7.08e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 7.0%:    51.26% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 6.61e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 7.5%:    47.90% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 6.20e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 8.0%:    44.96% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 5.84e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 8.5%:    42.36% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 5.52e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 9.0%:    40.05% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 5.24e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ± 9.5%:    37.98% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 4.98e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±10.0%:    36.12% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 4.75e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±10.5%:    34.43% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 4.54e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±11.0%:    32.90% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 4.34e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±11.5%:    31.50% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 4.16e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±12.0%:    30.22% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 4.00e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±12.5%:    29.03% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 3.85e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±13.0%:    27.94% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 3.71e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±13.5%:    26.93% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 3.58e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±14.0%:    25.99% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 3.46e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±14.5%:    25.11% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 3.35e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±15.0%:    24.29% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 3.24e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±15.5%:    23.53% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 3.14e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±16.0%:    22.81% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 3.05e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±16.5%:    22.14% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 2.96e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±17.0%:    21.50% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 2.88e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±17.5%:    20.90% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 2.80e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±18.0%:    20.33% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 2.73e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±18.5%:    19.80% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 2.66e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±19.0%:    19.29% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 2.59e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±19.5%:    18.81% APR
# Current price (token0/token1): 0.029195117140
# Current price (token1/token0): 34.25
# deltaL: 2.53e+14
# Average 24h volume (last 7 days): $74,261,935.29
#   ±20.0%:    18.35% APR
#
# [4/8] Processing pool 0x641c00a822e8b671738d32a431a4fb6074e5c79d
#
# 🔄 Analyzing pool 0x641c00a822e8b671738d32a431a4fb6074e5c79d...
# 📥 Forcing data fetch (no_cache=True)...
# 📥 Fetching data for pool 0x641c00a822e8b671738d32a431a4fb6074e5c79d...
# ✅ Valid pool found: WETH/USDT (Fee: 0.050%)
# ✅ Data saved for pool 0x641c00a822e8b671738d32a431a4fb6074e5c79d
# 📊 Pool: WETH/USDT (0.05%)
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 3.35e+17
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 0.5%:  1600.46% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.68e+17
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 1.0%:  1018.46% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.12e+17
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 1.5%:   747.35% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 8.41e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 2.0%:   590.54% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 6.73e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 2.5%:   488.32% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 5.62e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 3.0%:   416.41% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 4.82e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 3.5%:   363.07% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 4.22e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 4.0%:   321.92% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 3.76e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 4.5%:   289.22% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 3.39e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 5.0%:   262.60% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 3.08e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 5.5%:   240.50% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 2.83e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 6.0%:   221.88% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 2.61e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 6.5%:   205.96% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 2.43e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 7.0%:   192.19% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 2.27e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 7.5%:   180.18% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 2.13e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 8.0%:   169.59% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 2.01e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 8.5%:   160.20% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.90e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 9.0%:   151.80% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.80e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ± 9.5%:   144.26% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.71e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ±10.0%:   137.44% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.63e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ±10.5%:   131.24% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.56e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ±11.0%:   125.59% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.49e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ±11.5%:   120.41% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.43e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ±12.0%:   115.65% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.38e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ±12.5%:   111.26% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.32e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ±13.0%:   107.19% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.28e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ±13.5%:   103.42% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.23e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ±14.0%:    99.91% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.19e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ±14.5%:    96.63% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.15e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ±15.0%:    93.56% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.11e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ±15.5%:    90.69% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.08e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ±16.0%:    87.99% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.05e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ±16.5%:    85.45% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 1.02e+16
# Average 24h volume (last 7 days): $20,533,002.08
#   ±17.0%:    83.05% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 9.90e+15
# Average 24h volume (last 7 days): $20,533,002.08
#   ±17.5%:    80.79% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 9.64e+15
# Average 24h volume (last 7 days): $20,533,002.08
#   ±18.0%:    78.65% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 9.38e+15
# Average 24h volume (last 7 days): $20,533,002.08
#   ±18.5%:    76.62% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 9.14e+15
# Average 24h volume (last 7 days): $20,533,002.08
#   ±19.0%:    74.69% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 8.91e+15
# Average 24h volume (last 7 days): $20,533,002.08
#   ±19.5%:    72.87% APR
# Current price (token0/token1): 0.000287681298
# Current price (token1/token0): 3476.07
# deltaL: 8.70e+15
# Average 24h volume (last 7 days): $20,533,002.08
#   ±20.0%:    71.12% APR
#
# [5/8] Processing pool 0x6f38e884725a116c9c7fbf208e79fe8828a2595f
#
# 🔄 Analyzing pool 0x6f38e884725a116c9c7fbf208e79fe8828a2595f...
# 📥 Forcing data fetch (no_cache=True)...
# 📥 Fetching data for pool 0x6f38e884725a116c9c7fbf208e79fe8828a2595f...
# ✅ Valid pool found: WETH/USDC (Fee: 0.010%)
# ✅ Data saved for pool 0x6f38e884725a116c9c7fbf208e79fe8828a2595f
# 📊 Pool: WETH/USDC (0.01%)
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 3.35e+17
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 0.5%:  1077.16% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.68e+17
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 1.0%:   728.63% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.12e+17
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 1.5%:   550.84% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 8.40e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 2.0%:   443.01% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 6.73e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 2.5%:   370.63% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 5.61e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 3.0%:   318.68% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 4.82e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 3.5%:   279.58% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 4.22e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 4.0%:   249.09% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 3.76e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 4.5%:   224.65% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 3.38e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 5.0%:   204.61% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 3.08e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 5.5%:   187.88% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 2.83e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 6.0%:   173.72% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 2.61e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 6.5%:   161.56% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 2.43e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 7.0%:   151.01% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 2.27e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 7.5%:   141.77% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 2.13e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 8.0%:   133.61% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 2.01e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 8.5%:   126.35% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.90e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 9.0%:   119.85% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.80e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ± 9.5%:   113.99% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.71e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ±10.0%:   108.69% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.63e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ±10.5%:   103.87% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.56e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ±11.0%:    99.47% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.49e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ±11.5%:    95.42% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.43e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ±12.0%:    91.70% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.37e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ±12.5%:    88.27% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.32e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ±13.0%:    85.08% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.27e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ±13.5%:    82.13% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.23e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ±14.0%:    79.37% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.19e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ±14.5%:    76.80% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.15e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ±15.0%:    74.39% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.11e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ±15.5%:    72.13% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.08e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ±16.0%:    70.00% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.05e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ±16.5%:    68.00% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 1.02e+16
# Average 24h volume (last 7 days): $56,702,901.34
#   ±17.0%:    66.11% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 9.90e+15
# Average 24h volume (last 7 days): $56,702,901.34
#   ±17.5%:    64.33% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 9.63e+15
# Average 24h volume (last 7 days): $56,702,901.34
#   ±18.0%:    62.64% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 9.37e+15
# Average 24h volume (last 7 days): $56,702,901.34
#   ±18.5%:    61.04% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 9.13e+15
# Average 24h volume (last 7 days): $56,702,901.34
#   ±19.0%:    59.52% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 8.91e+15
# Average 24h volume (last 7 days): $56,702,901.34
#   ±19.5%:    58.08% APR
# Current price (token0/token1): 0.000287378144
# Current price (token1/token0): 3479.74
# deltaL: 8.69e+15
# Average 24h volume (last 7 days): $56,702,901.34
#   ±20.0%:    56.70% APR
#
# [6/8] Processing pool 0xc6f780497a95e246eb9449f5e4770916dcd6396a
#
# 🔄 Analyzing pool 0xc6f780497a95e246eb9449f5e4770916dcd6396a...
# 📥 Forcing data fetch (no_cache=True)...
# 📥 Fetching data for pool 0xc6f780497a95e246eb9449f5e4770916dcd6396a...
# ✅ Valid pool found: WETH/ARB (Fee: 0.050%)
# ✅ Data saved for pool 0xc6f780497a95e246eb9449f5e4770916dcd6396a
# 📊 Pool: WETH/ARB (0.05%)
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 4.88e+23
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 0.5%:  1166.82% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 2.44e+23
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 1.0%:   694.98% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 1.63e+23
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 1.5%:   495.21% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 1.22e+23
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 2.0%:   384.84% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 9.80e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 2.5%:   314.83% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 8.18e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 3.0%:   266.47% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 7.02e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 3.5%:   231.05% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 6.15e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 4.0%:   203.99% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 5.47e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 4.5%:   182.65% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 4.93e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 5.0%:   165.38% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 4.49e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 5.5%:   151.12% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 4.12e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 6.0%:   139.14% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 3.80e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 6.5%:   128.95% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 3.54e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 7.0%:   120.16% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 3.30e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 7.5%:   112.50% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 3.10e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 8.0%:   105.77% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 2.92e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 8.5%:    99.82% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 2.76e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 9.0%:    94.50% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 2.62e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ± 9.5%:    89.73% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 2.49e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±10.0%:    85.43% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 2.37e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±10.5%:    81.52% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 2.27e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±11.0%:    77.96% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 2.17e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±11.5%:    74.71% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 2.08e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±12.0%:    71.71% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 2.00e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±12.5%:    68.96% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 1.92e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±13.0%:    66.41% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 1.85e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±13.5%:    64.04% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 1.79e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±14.0%:    61.84% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 1.73e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±14.5%:    59.79% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 1.67e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±15.0%:    57.87% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 1.62e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±15.5%:    56.07% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 1.57e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±16.0%:    54.39% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 1.52e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±16.5%:    52.80% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 1.48e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±17.0%:    51.31% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 1.44e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±17.5%:    49.89% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 1.40e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±18.0%:    48.56% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 1.36e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±18.5%:    47.29% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 1.33e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±19.0%:    46.09% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 1.30e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±19.5%:    44.96% APR
# Current price (token0/token1): 0.000129426156
# Current price (token1/token0): 7726.41
# deltaL: 1.26e+22
# Average 24h volume (last 7 days): $20,014,914.63
#   ±20.0%:    43.87% APR
#
# [7/8] Processing pool 0xcda53b1f66614552f834ceef361a8d12a0b8dad8
#
# 🔄 Analyzing pool 0xcda53b1f66614552f834ceef361a8d12a0b8dad8...
# 📥 Forcing data fetch (no_cache=True)...
# 📥 Fetching data for pool 0xcda53b1f66614552f834ceef361a8d12a0b8dad8...
# ✅ Valid pool found: ARB/USDC (Fee: 0.050%)
# ✅ Data saved for pool 0xcda53b1f66614552f834ceef361a8d12a0b8dad8
# 📊 Pool: ARB/USDC (0.05%)
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 2.92e+19
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 0.5%:  1138.34% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 1.46e+19
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 1.0%:   893.87% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 9.77e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 1.5%:   736.17% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 7.34e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 2.0%:   626.00% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 5.88e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 2.5%:   544.68% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 4.90e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 3.0%:   482.19% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 4.21e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 3.5%:   432.67% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 3.69e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 4.0%:   392.45% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 3.28e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 4.5%:   359.15% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 2.96e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 5.0%:   331.11% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 2.69e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 5.5%:   307.18% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 2.47e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 6.0%:   286.51% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 2.28e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 6.5%:   268.49% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 2.12e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 7.0%:   252.62% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 1.98e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 7.5%:   238.56% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 1.86e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 8.0%:   226.00% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 1.75e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 8.5%:   214.71% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 1.66e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 9.0%:   204.52% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 1.57e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ± 9.5%:   195.27% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 1.49e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ±10.0%:   186.83% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 1.42e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ±10.5%:   179.10% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 1.36e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ±11.0%:   172.00% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 1.30e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ±11.5%:   165.45% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 1.25e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ±12.0%:   159.39% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 1.20e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ±12.5%:   153.76% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 1.16e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ±13.0%:   148.53% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 1.11e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ±13.5%:   143.65% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 1.07e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ±14.0%:   139.08% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 1.04e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ±14.5%:   134.80% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 1.00e+18
# Average 24h volume (last 7 days): $8,593,910.21
#   ±15.0%:   130.78% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 9.73e+17
# Average 24h volume (last 7 days): $8,593,910.21
#   ±15.5%:   127.00% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 9.44e+17
# Average 24h volume (last 7 days): $8,593,910.21
#   ±16.0%:   123.43% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 9.16e+17
# Average 24h volume (last 7 days): $8,593,910.21
#   ±16.5%:   120.07% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 8.89e+17
# Average 24h volume (last 7 days): $8,593,910.21
#   ±17.0%:   116.88% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 8.65e+17
# Average 24h volume (last 7 days): $8,593,910.21
#   ±17.5%:   113.87% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 8.41e+17
# Average 24h volume (last 7 days): $8,593,910.21
#   ±18.0%:   111.00% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 8.19e+17
# Average 24h volume (last 7 days): $8,593,910.21
#   ±18.5%:   108.28% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 7.98e+17
# Average 24h volume (last 7 days): $8,593,910.21
#   ±19.0%:   105.70% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 7.78e+17
# Average 24h volume (last 7 days): $8,593,910.21
#   ±19.5%:   103.23% APR
# Current price (token0/token1): 2.222754831413
# Current price (token1/token0): 0.45
# deltaL: 7.59e+17
# Average 24h volume (last 7 days): $8,593,910.21
#   ±20.0%:   100.88% APR
#
# [8/8] Processing pool 0x50e7b9293aef80c304234e86c84a01be8401c530
#
# 🔄 Analyzing pool 0x50e7b9293aef80c304234e86c84a01be8401c530...
# 📥 Forcing data fetch (no_cache=True)...
# 📥 Fetching data for pool 0x50e7b9293aef80c304234e86c84a01be8401c530...
# ✅ Valid pool found: PENDLE/USDT (Fee: 0.300%)
# ✅ Data saved for pool 0x50e7b9293aef80c304234e86c84a01be8401c530
# 📊 Pool: PENDLE/USDT (0.30%)
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 9.46e+18
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 0.5%:  1221.83% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 4.74e+18
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 1.0%:   991.13% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 3.16e+18
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 1.5%:   834.06% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 2.38e+18
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 2.0%:   720.21% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 1.90e+18
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 2.5%:   633.90% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 1.59e+18
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 3.0%:   566.21% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 1.36e+18
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 3.5%:   511.70% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 1.19e+18
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 4.0%:   466.85% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 1.06e+18
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 4.5%:   429.32% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 9.57e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 5.0%:   397.43% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 8.71e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 5.5%:   370.01% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 7.99e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 6.0%:   346.18% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 7.39e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 6.5%:   325.28% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 6.87e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 7.0%:   306.79% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 6.42e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 7.5%:   290.32% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 6.02e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 8.0%:   275.55% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 5.67e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 8.5%:   262.24% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 5.36e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 9.0%:   250.18% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 5.09e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ± 9.5%:   239.20% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 4.84e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±10.0%:   229.16% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 4.61e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±10.5%:   219.94% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 4.41e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±11.0%:   211.45% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 4.22e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±11.5%:   203.60% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 4.05e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±12.0%:   196.33% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 3.89e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±12.5%:   189.56% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 3.74e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±13.0%:   183.26% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 3.61e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±13.5%:   177.37% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 3.48e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±14.0%:   171.86% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 3.36e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±14.5%:   166.68% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 3.26e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±15.0%:   161.82% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 3.15e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±15.5%:   157.23% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 3.06e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±16.0%:   152.90% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 2.97e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±16.5%:   148.81% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 2.88e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±17.0%:   144.94% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 2.80e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±17.5%:   141.27% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 2.73e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±18.0%:   137.78% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 2.65e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±18.5%:   134.46% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 2.59e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±19.0%:   131.31% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 2.52e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±19.5%:   128.30% APR
# Current price (token0/token1): 0.239538615091
# Current price (token1/token0): 4.17
# deltaL: 2.46e+17
# Average 24h volume (last 7 days): $1,455,490.19
#   ±20.0%:   125.43% APR
#
# ✅ Results saved to multi_pool_apr_analysis_20250719_002402.csv
#
# 📊 Analysis Summary:
# Total valid results: 320
# Pools analyzed: 8

# %%
# Analysis and comparison
if results_df is not None and len(results_df) > 0:
    print("\n🏆 TOP PERFORMERS ANALYSIS")
    print("=" * 50)
    
    # Find best APR for each pool
    best_by_pool = results_df.loc[results_df.groupby('pool_address')['apr_percentage'].idxmax()]
    
    print("\n📈 Best APR per Pool:")
    for _, row in best_by_pool.iterrows():
        print(f"{row['pool_symbol']:20} | ±{row['range_percentage']:4.1f}% | {row['apr_percentage']:8.2f}% APR")
    
    # Overall best performer
    overall_best = results_df.loc[results_df['apr_percentage'].idxmax()]
    print(f"\n🥇 Overall Best:")
    print(f"Pool: {overall_best['pool_symbol']} ({overall_best['pool_address'][:10]}...)")
    print(f"Range: ±{overall_best['range_percentage']}%")
    print(f"APR: {overall_best['apr_percentage']:.2f}%")
    
    # Top 10 results
    print(f"\n🔟 Top 10 Results:")
    top_10 = results_df.nlargest(10, 'apr_percentage')
    for i, (_, row) in enumerate(top_10.iterrows(), 1):
        print(f"{i:2}. {row['pool_symbol']:15} | ±{row['range_percentage']:4.1f}% | {row['apr_percentage']:8.2f}% APR")
    
    # Range analysis
    print(f"\n📊 Range Analysis:")
    range_summary = results_df.groupby('range_percentage')['apr_percentage'].agg(['mean', 'max', 'count']).round(2)
    print(range_summary.head(10))
# Out:
# 🏆 TOP PERFORMERS ANALYSIS
# ==================================================
#
# 📈 Best APR per Pool:
# WBTC/WETH (0.05%)    | ± 0.5% |   675.02% APR
# PENDLE/USDT (0.30%)  | ± 0.5% |  1221.83% APR
# WBTC/USDT (0.05%)    | ± 0.5% |   369.50% APR
# WETH/USDT (0.05%)    | ± 0.5% |  1600.46% APR
# WETH/USDC (0.01%)    | ± 0.5% |  1077.16% APR
# WETH/USDC (0.05%)    | ± 0.5% |  1972.96% APR
# WETH/ARB (0.05%)     | ± 0.5% |  1166.82% APR
# ARB/USDC (0.05%)     | ± 0.5% |  1138.34% APR
#
# 🥇 Overall Best:
# Pool: WETH/USDC (0.05%) (0xc6962004...)
# Range: ±0.5%
# APR: 1972.96%
#
# 🔟 Top 10 Results:
#  1. WETH/USDC (0.05%) | ± 0.5% |  1972.96% APR
#  2. WETH/USDT (0.05%) | ± 0.5% |  1600.46% APR
#  3. PENDLE/USDT (0.30%) | ± 0.5% |  1221.83% APR
#  4. WETH/ARB (0.05%) | ± 0.5% |  1166.82% APR
#  5. ARB/USDC (0.05%) | ± 0.5% |  1138.34% APR
#  6. WETH/USDC (0.01%) | ± 0.5% |  1077.16% APR
#  7. WETH/USDT (0.05%) | ± 1.0% |  1018.46% APR
#  8. WETH/USDC (0.05%) | ± 1.0% |  1017.36% APR
#  9. PENDLE/USDT (0.30%) | ± 1.0% |   991.13% APR
# 10. ARB/USDC (0.05%) | ± 1.0% |   893.87% APR
#
# 📊 Range Analysis:
#                      mean      max  count
# range_percentage
# 0.5               1152.76  1972.96      8
# 1.0                736.78  1018.46      8
# 1.5                552.89   834.06      8
# 2.0                445.67   720.21      8
# 2.5                374.54   633.90      8
# 3.0                323.58   566.21      8
# 3.5                285.15   511.70      8
# 4.0                255.07   466.85      8
# 4.5                230.86   429.32      8
# 5.0                210.94   397.43      8

# %%
# Visualization (optional)
try:
    import matplotlib.pyplot as plt
    import matplotlib.colors as mcolors
    import numpy as np
    
    if results_df is not None and len(results_df) > 0:
        # Get unique base pool symbols and fee tiers for color mapping
        base_pools = results_df['base_pool_symbol'].unique()
        fee_tiers = results_df['fee_tier_pct'].unique()
        
        # Generate dynamic colors for each unique combination of pool + fee tier
        # This ensures every line has a distinct color
        pool_fee_combinations = []
        for base_pool in base_pools:
            base_pool_data = results_df[results_df['base_pool_symbol'] == base_pool]
            for fee_tier in sorted(base_pool_data['fee_tier_pct'].unique()):
                pool_fee_combinations.append((base_pool, fee_tier))
        
        # Use a diverse color palette for maximum distinction
        n_combinations = len(pool_fee_combinations)
        
        # Combine multiple colormaps for better color diversity
        colormap1 = plt.cm.Set1
        colormap2 = plt.cm.Dark2
        colormap3 = plt.cm.tab10
        
        combination_colors = {}
        for i, (pool, fee) in enumerate(pool_fee_combinations):
            # Use different colormaps to ensure maximum distinction
            if i < 9:
                color = colormap1(i / 8)
                # Ensure color is dark enough
                rgb = np.array(color[:3])
                while np.mean(rgb) > 0.7:  # If too light
                    rgb = rgb * 0.8  # Darken it
                color = (*rgb, color[3])  # Keep alpha channel
            elif i < 17:
                color = colormap2((i - 9) / 7)
                rgb = np.array(color[:3])
                while np.mean(rgb) > 0.7:
                    rgb = rgb * 0.8
                color = (*rgb, color[3])
            else:
                color = colormap3((i - 17) / 9)
                rgb = np.array(color[:3])
                while np.mean(rgb) > 0.7:
                    rgb = rgb * 0.8
                color = (*rgb, color[3])
            combination_colors[(pool, fee)] = color
        
        # Define line styles and markers for fee tiers
        fee_tier_styles = {
            0.0001: ('-', 'o'),   # Solid line with circle
            0.0005: ('--', 's'),  # Dashed line with square
            0.003: (':', '^'),    # Dotted line with triangle
            0.01: ('-.', 'D')     # Dash-dot line with diamond
        }
        
        # Create figure with optimized size for full width usage
        fig, ax = plt.subplots(figsize=(16, 8))
        
        # Update font sizes for better readability
        plt.rcParams.update({
            'font.size': 11,
            'axes.labelsize': 13,
            'axes.titlesize': 15,
            'xtick.labelsize': 11,
            'ytick.labelsize': 11,
            'legend.fontsize': 10
        })
        
        # Plot each pool with its fee tier
        for base_pool in base_pools:
            base_pool_data = results_df[results_df['base_pool_symbol'] == base_pool]
            
            # Plot each fee tier for this base pool
            for fee_tier in sorted(base_pool_data['fee_tier_pct'].unique()):
                fee_tier_data = base_pool_data[base_pool_data['fee_tier_pct'] == fee_tier]
                
                # Create label with fee tier
                label = f"{base_pool} ({fee_tier:.2%})"
                
                # Get line style and marker for this fee tier
                line_style, marker = fee_tier_styles.get(fee_tier, ('-', 'o'))
                
                # Plot with unique color for each line
                ax.plot(fee_tier_data['range_percentage'], 
                       fee_tier_data['apr_percentage'],
                       linestyle=line_style,
                       marker=marker,
                       color=combination_colors[(base_pool, fee_tier)],
                       label=label,
                       linewidth=2.5,
                       markersize=7,
                       markevery=5,
                       markerfacecolor='white',
                       markeredgewidth=2,
                       alpha=0.9)
        
        # Set labels and title
        ax.set_xlabel('Range Percentage (±%)', fontweight='bold')
        ax.set_ylabel('APR (%)', fontweight='bold')
        ax.set_title('Uniswap V3 APR vs Price Range - Multi-Pool Comparison', 
                    fontweight='bold', pad=20)
        
        # Enhance background and grid
        ax.set_facecolor('#f8f8f8')
        ax.grid(True, linestyle='--', alpha=0.7, color='white', linewidth=1.5)
        ax.set_axisbelow(True)
        
        # Add log scale for y-axis
        ax.set_yscale('log')
        
        # Create floating legend that doesn't interfere with the plot
        # Position it in the upper right corner with some padding
        legend = ax.legend(
            loc='upper right',
            bbox_to_anchor=(0.98, 0.98),
            fontsize=10,
            frameon=True,
            fancybox=True,
            shadow=True,
            framealpha=0.95,
            facecolor='white',
            edgecolor='gray',
            title='Pool Pairs',
            title_fontsize=11,
            borderpad=0.5,
            columnspacing=0.5,
            handlelength=1.5,
            handletextpad=0.5
        )
        
        # Make legend title bold
        legend.get_title().set_fontweight('bold')
        
        # Ensure tight layout to maximize plot area
        plt.tight_layout()
        
        # Optional: Add minor ticks for better readability
        ax.minorticks_on()
        ax.tick_params(which='minor', length=3, width=0.5, color='gray')
        
        # Add subtle border around the plot
        for spine in ax.spines.values():
            spine.set_edgecolor('gray')
            spine.set_linewidth(1.2)
        
        # Show the plot
        plt.show()
        
        # Optional: Save the figure with high DPI for better quality
        # plt.savefig('uniswap_v3_apr_analysis.png', dpi=300, bbox_inches='tight', 
        #             facecolor='white', edgecolor='none')
        
except ImportError:
    print("\n📊 Matplotlib not available for plotting")
except Exception as e:
    print(f"\n❌ Error creating plot: {str(e)}")

# %%
# Summary statistics
if results_df is not None and len(results_df) > 0:
    print("\n📈 DETAILED STATISTICS")
    print("=" * 60)
    
    print(f"\nOverall Statistics:")
    print(f"Mean APR: {results_df['apr_percentage'].mean():.2f}%")
    print(f"Median APR: {results_df['apr_percentage'].median():.2f}%")
    print(f"Std Dev: {results_df['apr_percentage'].std():.2f}%")
    print(f"Min APR: {results_df['apr_percentage'].min():.2f}%")
    print(f"Max APR: {results_df['apr_percentage'].max():.2f}%")
    
    # Group by base pool symbol and fee tier
    print(f"\nBy Pool and Fee Tier:")
    pool_fee_stats = results_df.groupby(['base_pool_symbol', 'fee_tier_pct'])['apr_percentage'].agg([
        ('mean', 'mean'),
        ('max', 'max'),
        ('min', 'min'),
        ('count', 'count')
    ]).round(2)
    
    # Format the index for better display
    pool_fee_stats.index = [f"{pool} ({fee:.2%})" for pool, fee in pool_fee_stats.index]
    print(pool_fee_stats)
    
    # Compare fee tiers for each base pool
    print(f"\n📊 Fee Tier Comparison by Pool:")
    for base_pool in results_df['base_pool_symbol'].unique():
        pool_data = results_df[results_df['base_pool_symbol'] == base_pool]
        print(f"\n{base_pool}:")
        for fee_tier in sorted(pool_data['fee_tier_pct'].unique()):
            fee_data = pool_data[pool_data['fee_tier_pct'] == fee_tier]
            max_apr = fee_data['apr_percentage'].max()
            optimal_range = fee_data.loc[fee_data['apr_percentage'].idxmax()]['range_percentage']
            print(f"  {fee_tier:.2%} Fee Tier | Max APR: {max_apr:8.2f}% | Optimal Range: ±{optimal_range:4.1f}%")
    
    print(f"\nBy Range:")
    range_stats = results_df.groupby('range_percentage')['apr_percentage'].agg(['mean', 'max', 'count']).round(2)
    print(range_stats.head(15))
    
    # Find optimal ranges for each pool and fee tier combination
    print(f"\n🎯 Optimal Ranges by Pool and Fee Tier:")
    optimal_ranges = results_df.loc[results_df.groupby(['base_pool_symbol', 'fee_tier_pct'])['apr_percentage'].idxmax()]
    optimal_ranges = optimal_ranges.sort_values(['base_pool_symbol', 'fee_tier_pct'])
    
    for _, row in optimal_ranges.iterrows():
        print(f"{row['base_pool_symbol']} ({row['fee_tier_pct']:.2%}) | "
              f"Optimal: ±{row['range_percentage']:4.1f}% | "
              f"APR: {row['apr_percentage']:8.2f}%")
# Out:
# 📈 DETAILED STATISTICS
# ============================================================
#
# Overall Statistics:
# Mean APR: 191.21%
# Median APR: 112.33%
# Std Dev: 245.09%
# Min APR: 11.61%
# Max APR: 1972.96%
#
# By Pool and Fee Tier:
#                        mean      max     min  count
# ARB/USDC (0.05%)     274.35  1138.34  100.88     40
# PENDLE/USDT (0.30%)  323.80  1221.83  125.43     40
# WBTC/USDT (0.05%)     45.16   369.50   11.61     40
# WBTC/WETH (0.05%)     75.18   675.02   18.35     40
# WETH/ARB (0.05%)     160.33  1166.82   43.87     40
# WETH/USDC (0.01%)    184.51  1077.16   56.70     40
# WETH/USDC (0.05%)    221.14  1972.96   54.29     40
# WETH/USDT (0.05%)    245.23  1600.46   71.12     40
#
# 📊 Fee Tier Comparison by Pool:
#
# WBTC/USDT:
#   0.05% Fee Tier | Max APR:   369.50% | Optimal Range: ± 0.5%
#
# WETH/USDC:
#   0.01% Fee Tier | Max APR:  1077.16% | Optimal Range: ± 0.5%
#   0.05% Fee Tier | Max APR:  1972.96% | Optimal Range: ± 0.5%
#
# WBTC/WETH:
#   0.05% Fee Tier | Max APR:   675.02% | Optimal Range: ± 0.5%
#
# WETH/USDT:
#   0.05% Fee Tier | Max APR:  1600.46% | Optimal Range: ± 0.5%
#
# WETH/ARB:
#   0.05% Fee Tier | Max APR:  1166.82% | Optimal Range: ± 0.5%
#
# ARB/USDC:
#   0.05% Fee Tier | Max APR:  1138.34% | Optimal Range: ± 0.5%
#
# PENDLE/USDT:
#   0.30% Fee Tier | Max APR:  1221.83% | Optimal Range: ± 0.5%
#
# By Range:
#                      mean      max  count
# range_percentage
# 0.5               1152.76  1972.96      8
# 1.0                736.78  1018.46      8
# 1.5                552.89   834.06      8
# 2.0                445.67   720.21      8
# 2.5                374.54   633.90      8
# 3.0                323.58   566.21      8
# 3.5                285.15   511.70      8
# 4.0                255.07   466.85      8
# 4.5                230.86   429.32      8
# 5.0                210.94   397.43      8
# 5.5                194.24   370.01      8
# 6.0                180.05   346.18      8
# 6.5                167.82   325.28      8
# 7.0                157.18   306.79      8
# 7.5                147.83   290.32      8
#
# 🎯 Optimal Ranges by Pool and Fee Tier:
# ARB/USDC (0.05%) | Optimal: ± 0.5% | APR:  1138.34%
# PENDLE/USDT (0.30%) | Optimal: ± 0.5% | APR:  1221.83%
# WBTC/USDT (0.05%) | Optimal: ± 0.5% | APR:   369.50%
# WBTC/WETH (0.05%) | Optimal: ± 0.5% | APR:   675.02%
# WETH/ARB (0.05%) | Optimal: ± 0.5% | APR:  1166.82%
# WETH/USDC (0.01%) | Optimal: ± 0.5% | APR:  1077.16%
# WETH/USDC (0.05%) | Optimal: ± 0.5% | APR:  1972.96%
# WETH/USDT (0.05%) | Optimal: ± 0.5% | APR:  1600.46%
